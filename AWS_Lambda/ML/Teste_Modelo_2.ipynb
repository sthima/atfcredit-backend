# %%
from Modules.Modelo2.Predictor import Predictor

# %%
Predictor().train_new_model()
# Out:
# model:   0%|                                                                                   | 0/100 [00:00<?, ?it/s]
#      Faturamento  Funcionarios  \
# 0            8.0           5.0
# 1            0.0           0.0
# 2            5.0           5.0
# 3            0.0           0.0
# 4            7.0           5.0
# ..           ...           ...
# 511          0.0           0.0
# 512          0.0           0.0
# 513          0.0           0.0
# 514          0.0           0.0
# 515          0.0           0.0
#
#                                                   Nome   OpcaoTributaria  \
# 0              BELLA JANELA INDUSTRIA DE CORTINAS LTDA        LUCRO REAL
# 1                 CORDOARIA SAO LEOPOLDO ORIGINAL LTDA        LUCRO REAL
# 2                             CARTOMEC EMBALAGENS LTDA        LUCRO REAL
# 3                             INJETADOS MAGUIBETH LTDA  SIMPLES NACIONAL
# 4                     ALTUS SISTEMAS DE AUTOMACAO S.A.        LUCRO REAL
# ..                                                 ...               ...
# 511  ATIVA BRASIL INDUSTRIA COMERCIO DE COSMETICOS ...   LUCRO PRESUMIDO
# 512                               AMBIENT SOFAS EIRELI  SIMPLES NACIONAL
# 513                            CONFECCOES CHAPLIN LTDA   LUCRO PRESUMIDO
# 514    INDUSTRIA E COMERCIO DE CONFECCOES D'CARLO LTDA  SIMPLES NACIONAL
# 515  AELBRA EDUCACAO SUPERIOR - GRADUACAO E POS-GRA...            ISENTO
#
#      Porte  ReceitaAbertura  ReceitaAtividade  ReceitaCapitalSocial  \
# 0        2               28             13.51           64700000.00
# 1        2               15             13.53           21967500.00
# 2        2               39             22.22             600000.00
# 3        1               26             22.29            1000000.00
# 4        2               32             26.51            4370144.08
# ..     ...              ...               ...                   ...
# 511      1               21             20.63            2455655.00
# 512      1                8             31.01              88000.00
# 513      2               35             14.22              50000.00
# 514      1               27             14.12              40000.00
# 515      2               51             85.31               5000.00
#
#      ReceitaNaturezaJuridica ReceitaSituacao  ReceitaSituacaoEspecial  \
# 0                         12           ATIVA                      0.0
# 1                         12           ATIVA                      0.0
# 2                         12           ATIVA                      0.0
# 3                         12           ATIVA                      0.0
# 4                          4           ATIVA                      0.0
# ..                       ...             ...                      ...
# 511                        9           ATIVA                      0.0
# 512                        9           ATIVA                      0.0
# 513                       12           ATIVA                      0.0
# 514                       12           ATIVA                      0.0
# 515                        4           ATIVA                      1.0
#
#      TotalProtesto  UfEndereco  ValorProtesto            cnpj  resultado
# 0                0         8.0           0.00  72344591000125        0.0
# 1               63        14.0     8625700.78  08651140000131        1.0
# 2                0        14.0           0.00  87973459000150        0.0
# 3                0        14.0           0.00  00746174000106        0.0
# 4                2        14.0       53902.25  92859974000143        0.0
# ..             ...         ...            ...             ...        ...
# 511              0         8.0           0.00  04203927000180        0.0
# 512              0         8.0           0.00  17778031000170        0.0
# 513             14         8.0      848872.93  79286480000159        0.0
# 514             -1         8.0           0.00  00200488000109        0.0
# 515             -1        14.0           0.00  88332580000165        1.0
#
# [516 rows x 16 columns]
# model:   4%| | 4/100 [00:05<02:11,  1.37s/it, best_iter=1, best_pos=[31 44  2  0  2  2  4  5  6  0  6  0  6  0  3  1  1C:\Users\rafae\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 304, in fit
#     X, y = self._validate_data(X, y, multi_output=True,
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\base.py", line 433, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 871, in check_X_y
#     X = check_array(X, accept_sparse=accept_sparse,
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 720, in check_array
#     _assert_all_finite(array,
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 103, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float32').
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\rafae\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 304, in fit
#     X, y = self._validate_data(X, y, multi_output=True,
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\base.py", line 433, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 871, in check_X_y
#     X = check_array(X, accept_sparse=accept_sparse,
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 720, in check_array
#     _assert_all_finite(array,
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 103, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float32').
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\rafae\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 304, in fit
#     X, y = self._validate_data(X, y, multi_output=True,
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\base.py", line 433, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 871, in check_X_y
#     X = check_array(X, accept_sparse=accept_sparse,
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 720, in check_array
#     _assert_all_finite(array,
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 103, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float32').
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\rafae\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 304, in fit
#     X, y = self._validate_data(X, y, multi_output=True,
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\base.py", line 433, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 871, in check_X_y
#     X = check_array(X, accept_sparse=accept_sparse,
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 720, in check_array
#     _assert_all_finite(array,
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 103, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float32').
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\rafae\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 304, in fit
#     X, y = self._validate_data(X, y, multi_output=True,
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\base.py", line 433, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 871, in check_X_y
#     X = check_array(X, accept_sparse=accept_sparse,
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 720, in check_array
#     _assert_all_finite(array,
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 103, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float32').
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\rafae\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 304, in fit
#     X, y = self._validate_data(X, y, multi_output=True,
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\base.py", line 433, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 871, in check_X_y
#     X = check_array(X, accept_sparse=accept_sparse,
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 720, in check_array
#     _assert_all_finite(array,
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 103, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float32').
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\rafae\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 304, in fit
#     X, y = self._validate_data(X, y, multi_output=True,
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\base.py", line 433, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 871, in check_X_y
#     X = check_array(X, accept_sparse=accept_sparse,
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 720, in check_array
#     _assert_all_finite(array,
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 103, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float32').
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\rafae\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 304, in fit
#     X, y = self._validate_data(X, y, multi_output=True,
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\base.py", line 433, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 871, in check_X_y
#     X = check_array(X, accept_sparse=accept_sparse,
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 720, in check_array
#     _assert_all_finite(array,
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 103, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float32').
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\rafae\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 304, in fit
#     X, y = self._validate_data(X, y, multi_output=True,
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\base.py", line 433, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 871, in check_X_y
#     X = check_array(X, accept_sparse=accept_sparse,
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 720, in check_array
#     _assert_all_finite(array,
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 103, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float32').
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\rafae\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 304, in fit
#     X, y = self._validate_data(X, y, multi_output=True,
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\base.py", line 433, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 871, in check_X_y
#     X = check_array(X, accept_sparse=accept_sparse,
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 720, in check_array
#     _assert_all_finite(array,
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 103, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float32').
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\rafae\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 304, in fit
#     X, y = self._validate_data(X, y, multi_output=True,
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\base.py", line 433, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 871, in check_X_y
#     X = check_array(X, accept_sparse=accept_sparse,
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 720, in check_array
#     _assert_all_finite(array,
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 103, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float32').
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\rafae\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 304, in fit
#     X, y = self._validate_data(X, y, multi_output=True,
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\base.py", line 433, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 871, in check_X_y
#     X = check_array(X, accept_sparse=accept_sparse,
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 720, in check_array
#     _assert_all_finite(array,
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 103, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float32').
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\rafae\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 304, in fit
#     X, y = self._validate_data(X, y, multi_output=True,
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\base.py", line 433, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 871, in check_X_y
#     X = check_array(X, accept_sparse=accept_sparse,
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 720, in check_array
#     _assert_all_finite(array,
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 103, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float32').
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\rafae\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 304, in fit
#     X, y = self._validate_data(X, y, multi_output=True,
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\base.py", line 433, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 871, in check_X_y
#     X = check_array(X, accept_sparse=accept_sparse,
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 720, in check_array
#     _assert_all_finite(array,
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 103, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float32').
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# model:  39%|▍| 39/100 [00:49<01:19,  1.31s/it, best_iter=21, best_pos=[ 25 145   0   4   1   3   5   4   3   6   4   6 C:\Users\rafae\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 304, in fit
#     X, y = self._validate_data(X, y, multi_output=True,
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\base.py", line 433, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 871, in check_X_y
#     X = check_array(X, accept_sparse=accept_sparse,
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 720, in check_array
#     _assert_all_finite(array,
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 103, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float32').
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\rafae\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 304, in fit
#     X, y = self._validate_data(X, y, multi_output=True,
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\base.py", line 433, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 871, in check_X_y
#     X = check_array(X, accept_sparse=accept_sparse,
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 720, in check_array
#     _assert_all_finite(array,
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 103, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float32').
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\rafae\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 304, in fit
#     X, y = self._validate_data(X, y, multi_output=True,
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\base.py", line 433, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 871, in check_X_y
#     X = check_array(X, accept_sparse=accept_sparse,
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 720, in check_array
#     _assert_all_finite(array,
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 103, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float32').
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\rafae\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 304, in fit
#     X, y = self._validate_data(X, y, multi_output=True,
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\base.py", line 433, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 871, in check_X_y
#     X = check_array(X, accept_sparse=accept_sparse,
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 720, in check_array
#     _assert_all_finite(array,
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 103, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float32').
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\rafae\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 304, in fit
#     X, y = self._validate_data(X, y, multi_output=True,
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\base.py", line 433, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 871, in check_X_y
#     X = check_array(X, accept_sparse=accept_sparse,
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 720, in check_array
#     _assert_all_finite(array,
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 103, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float32').
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\rafae\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 304, in fit
#     X, y = self._validate_data(X, y, multi_output=True,
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\base.py", line 433, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 871, in check_X_y
#     X = check_array(X, accept_sparse=accept_sparse,
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 720, in check_array
#     _assert_all_finite(array,
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 103, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float32').
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\rafae\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 304, in fit
#     X, y = self._validate_data(X, y, multi_output=True,
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\base.py", line 433, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 871, in check_X_y
#     X = check_array(X, accept_sparse=accept_sparse,
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 720, in check_array
#     _assert_all_finite(array,
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 103, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float32').
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# model:  50%|▌| 50/100 [01:02<01:05,  1.31s/it, best_iter=21, best_pos=[ 25 145   0   4   1   3   5   4   3   6   4   6 C:\Users\rafae\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 304, in fit
#     X, y = self._validate_data(X, y, multi_output=True,
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\base.py", line 433, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 871, in check_X_y
#     X = check_array(X, accept_sparse=accept_sparse,
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 720, in check_array
#     _assert_all_finite(array,
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 103, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float32').
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\rafae\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 304, in fit
#     X, y = self._validate_data(X, y, multi_output=True,
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\base.py", line 433, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 871, in check_X_y
#     X = check_array(X, accept_sparse=accept_sparse,
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 720, in check_array
#     _assert_all_finite(array,
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 103, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float32').
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\rafae\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 304, in fit
#     X, y = self._validate_data(X, y, multi_output=True,
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\base.py", line 433, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 871, in check_X_y
#     X = check_array(X, accept_sparse=accept_sparse,
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 720, in check_array
#     _assert_all_finite(array,
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 103, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float32').
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\rafae\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 304, in fit
#     X, y = self._validate_data(X, y, multi_output=True,
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\base.py", line 433, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 871, in check_X_y
#     X = check_array(X, accept_sparse=accept_sparse,
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 720, in check_array
#     _assert_all_finite(array,
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 103, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float32').
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\rafae\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 304, in fit
#     X, y = self._validate_data(X, y, multi_output=True,
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\base.py", line 433, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 871, in check_X_y
#     X = check_array(X, accept_sparse=accept_sparse,
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 720, in check_array
#     _assert_all_finite(array,
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 103, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float32').
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\rafae\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 304, in fit
#     X, y = self._validate_data(X, y, multi_output=True,
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\base.py", line 433, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 871, in check_X_y
#     X = check_array(X, accept_sparse=accept_sparse,
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 720, in check_array
#     _assert_all_finite(array,
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 103, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float32').
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\rafae\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 304, in fit
#     X, y = self._validate_data(X, y, multi_output=True,
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\base.py", line 433, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 871, in check_X_y
#     X = check_array(X, accept_sparse=accept_sparse,
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 720, in check_array
#     _assert_all_finite(array,
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 103, in _assert_all_finite
#     raise ValueError(
# ...
#     X = check_array(X, accept_sparse=accept_sparse,
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 720, in check_array
#     _assert_all_finite(array,
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 103, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float32').
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\rafae\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 304, in fit
#     X, y = self._validate_data(X, y, multi_output=True,
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\base.py", line 433, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 871, in check_X_y
#     X = check_array(X, accept_sparse=accept_sparse,
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 720, in check_array
#     _assert_all_finite(array,
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 103, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float32').
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\rafae\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 304, in fit
#     X, y = self._validate_data(X, y, multi_output=True,
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\base.py", line 433, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 871, in check_X_y
#     X = check_array(X, accept_sparse=accept_sparse,
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 720, in check_array
#     _assert_all_finite(array,
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 103, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float32').
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# model:  97%|▉| 97/100 [01:53<00:03,  1.06s/it, best_iter=62, best_pos=[ 30 106   3   3   1   0   6   5   1   6   6   6 C:\Users\rafae\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 304, in fit
#     X, y = self._validate_data(X, y, multi_output=True,
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\base.py", line 433, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 871, in check_X_y
#     X = check_array(X, accept_sparse=accept_sparse,
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 720, in check_array
#     _assert_all_finite(array,
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 103, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float32').
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\rafae\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 304, in fit
#     X, y = self._validate_data(X, y, multi_output=True,
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\base.py", line 433, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 871, in check_X_y
#     X = check_array(X, accept_sparse=accept_sparse,
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 720, in check_array
#     _assert_all_finite(array,
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 103, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float32').
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\rafae\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 304, in fit
#     X, y = self._validate_data(X, y, multi_output=True,
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\base.py", line 433, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 871, in check_X_y
#     X = check_array(X, accept_sparse=accept_sparse,
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 720, in check_array
#     _assert_all_finite(array,
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 103, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float32').
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\rafae\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 304, in fit
#     X, y = self._validate_data(X, y, multi_output=True,
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\base.py", line 433, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 871, in check_X_y
#     X = check_array(X, accept_sparse=accept_sparse,
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 720, in check_array
#     _assert_all_finite(array,
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 103, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float32').
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\rafae\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 304, in fit
#     X, y = self._validate_data(X, y, multi_output=True,
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\base.py", line 433, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 871, in check_X_y
#     X = check_array(X, accept_sparse=accept_sparse,
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 720, in check_array
#     _assert_all_finite(array,
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 103, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float32').
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\rafae\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 304, in fit
#     X, y = self._validate_data(X, y, multi_output=True,
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\base.py", line 433, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 871, in check_X_y
#     X = check_array(X, accept_sparse=accept_sparse,
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 720, in check_array
#     _assert_all_finite(array,
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 103, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float32').
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\rafae\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 304, in fit
#     X, y = self._validate_data(X, y, multi_output=True,
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\base.py", line 433, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 871, in check_X_y
#     X = check_array(X, accept_sparse=accept_sparse,
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 720, in check_array
#     _assert_all_finite(array,
#   File "C:\Users\rafae\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 103, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float32').
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# Results: 'model'
#    Best score: 0.8082191780821918
#    Best parameter:
#       'min_samples_split'           : 35
#       'max_depth'                   : 109
#       'test_size'                   : 0.25
#       'Faturamento'                 : <ufunc 'square'>
#       'Funcionarios'                : False
#       'Porte'                       : True
#       'ReceitaAbertura'             : <ufunc 'cos'>
#       'ReceitaAtividade'            : <ufunc 'sin'>
#       'ReceitaCapitalSocial'        : False
#       'ReceitaNaturezaJuridica'     : <ufunc 'cos'>
#       'ReceitaSituacaoEspecial'     : <ufunc 'cos'>
#       'TotalProtesto'               : <ufunc 'cos'>
#       'UfEndereco'                  : True
#       'ValorProtesto'               : <ufunc 'sqrt'>
#       'ValorProtesto_cut'           : 11
#       'ReceitaAbertura_cut'         : 0
#       'ReceitaAtividade_cut'        : 0
#       'ReceitaCapitalSocial_cut'    : 7
#       'ReceitaNaturezaJuridica_cut' : 3
#
#    Evaluation time   : 115.47312617301941 sec    [99.88 %]
#    Optimization time : 0.13727259635925293 sec    [0.12 %]
#    Iteration time    : 115.61039876937866 sec    [1.16 sec/iter]
# 0.8082191780821918

# %%
from os import error
import pymongo
import pandas as pd
import json
from hyperactive import Hyperactive
from hyperactive import SimulatedAnnealingOptimizer
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score
import numpy as np
from sklearn.decomposition import PCA
from Modules.Modelo2.ClearData import ClearData
import tempfile
import boto3
import joblib
import botocore
import os

CONNETCION_MONGO = "mongodb+srv://atfUser:mvOX8tCv5Tv4pvJU@atfcluster.t51do.mongodb.net/test"
AWS_ACCESS_KEY = "AKIAVTWL6PT5PMSLZ6KP"
AWS_SECRET_KEY = "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"

# %%
def _get_train_data():
    myclient = pymongo.MongoClient(CONNETCION_MONGO)
    mydb = myclient["atf_score"]
    mycol = mydb['feature-collection']
    cursor = mycol.find({'resultado': {'$ne': -1}, "vadu_info": {"$exists": True}})

    df = pd.DataFrame(list(cursor))
    new_df = df['vadu_info'].apply(lambda x: pd.Series(x))
    new_df[['cnpj','resultado']] = df[['cnpj','resultado']]

    return new_df

df = _get_train_data()

# %%
ClearD = ClearData(df)
new_df = ClearD.clear_df()

# %%
X = new_df.drop(columns = ['cnpj','resultado','Nome','OpcaoTributaria'])

# %%
X['ReceitaSituacao'].value_counts()
# Out:
# ATIVA    516
# Name: ReceitaSituacao, dtype: int64
