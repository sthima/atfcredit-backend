# %%
import pymongo
import pandas as pd
CONNETCION_MONGO = "mongodb+srv://atfUser:mvOX8tCv5Tv4pvJU@atfcluster.t51do.mongodb.net/test"
myclient = pymongo.MongoClient(CONNETCION_MONGO)
mydb = myclient["atf_score"]
mycol = mydb['cut-rules-collection']
cursor = mycol.find()
df = pd.DataFrame(list(cursor)).iloc[0]

# %%
type(df.iloc[0]['UfEndereco'])
# Out:
# list

# %%
CONNETCION_MONGO = "mongodb+srv://atfUser:mvOX8tCv5Tv4pvJU@atfcluster.t51do.mongodb.net/test"
myclient = pymongo.MongoClient(CONNETCION_MONGO)
mydb = myclient["atf_score"]
mycol = mydb['feature-collection']
cursor = mycol.find()
df = pd.DataFrame(list(cursor))

# %%
new_df = df['vadu_info'].apply(lambda x: pd.Series(x))
new_df[['cnpj','resultado']] = df[['cnpj','resultado']]

# %%
from Modules.CutMetrics import CutMetrics

aux = CutMetrics.filter(new_df)
# Out:
# 62048
# 21581
# 18582
# 18292
# 15986
# 15961
# 15163
# 11689
# 5695

# %%
new_df.loc[new_df['cnpj'].isin(aux['cnpj']), 'dado_valido'] = True
new_df.loc[~new_df['cnpj'].isin(aux['cnpj']), 'dado_valido'] = False

# %%
df_save = pd.concat([new_df[['cnpj','dado_valido']],df[['cnpj','dado_valido']].dropna()]).drop_duplicates(keep=False).reset_index(drop = True)

# %%
17:28
# Out:
#                  cnpj dado_valido
# 0      07539696000178       False
# 1      15708129000126       False
# 2      28276482000126       False
# 3      32835258000102       False
# 4      00974362000183       False
# ...               ...         ...
# 35406  05514086000194        True
# 35407  08632355000105        True
# 35408  07321910000115        True
# 35409  03424310000121        True
# 35410  02765257000160        True
#
# [35411 rows x 2 columns]

# %%
mycol.update_one

# %%
for i, line in df_save.iterrows():
    query = {'cnpj':line['cnpj']}
    key = {'$set': {'dado_valido':line['dado_valido']}}
    mycol.update_one(query,key)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-91-77a6f5301521> in <module>
#       2     query = {'cnpj':line['cnpj']}
#       3     key = {'$set': {'dado_valido':line['dado_valido']}}
# ----> 4     mycol.update_one(query,key)
#
# ~\anaconda3\lib\site-packages\pymongo\collection.py in update_one(self, filter, update, upsert, bypass_document_validation, collation, array_filters, hint, session)
#    1017         write_concern = self._write_concern_for(session)
#    1018         return UpdateResult(
# -> 1019             self._update_retryable(
#    1020                 filter, update, upsert, check_keys=False,
#    1021                 write_concern=write_concern,
#
# ~\anaconda3\lib\site-packages\pymongo\collection.py in _update_retryable(self, criteria, document, upsert, check_keys, multi, manipulate, write_concern, op_id, ordered, bypass_doc_val, collation, array_filters, hint, session)
#     866                 retryable_write=retryable_write)
#     867
# --> 868         return self.__database.client._retryable_write(
#     869             (write_concern or self.write_concern).acknowledged and not multi,
#     870             _update, session)
#
# ~\anaconda3\lib\site-packages\pymongo\mongo_client.py in _retryable_write(self, retryable, func, session)
#    1496         """Internal retryable write helper."""
#    1497         with self._tmp_session(session) as s:
# -> 1498             return self._retry_with_session(retryable, func, s, None)
#    1499
#    1500     def _handle_getlasterror(self, address, error_msg):
#
# ~\anaconda3\lib\site-packages\pymongo\mongo_client.py in _retry_with_session(self, retryable, func, session, bulk)
#    1382         retryable = (retryable and self.retry_writes
#    1383                      and session and not session.in_transaction)
# -> 1384         return self._retry_internal(retryable, func, session, bulk)
#    1385
#    1386     def _retry_internal(self, retryable, func, session, bulk):
#
# ~\anaconda3\lib\site-packages\pymongo\mongo_client.py in _retry_internal(self, retryable, func, session, bulk)
#    1414                             raise last_error
#    1415                         retryable = False
# -> 1416                     return func(session, sock_info, retryable)
#    1417             except ServerSelectionTimeoutError:
#    1418                 if is_retrying():
#
# ~\anaconda3\lib\site-packages\pymongo\collection.py in _update(session, sock_info, retryable_write)
#     858         """Internal update / replace helper."""
#     859         def _update(session, sock_info, retryable_write):
# --> 860             return self._update(
#     861                 sock_info, criteria, document, upsert=upsert,
#     862                 check_keys=check_keys, multi=multi, manipulate=manipulate,
#
# ~\anaconda3\lib\site-packages\pymongo\collection.py in _update(self, sock_info, criteria, document, upsert, check_keys, multi, manipulate, write_concern, op_id, ordered, bypass_doc_val, collation, array_filters, hint, session, retryable_write)
#     827         # The command result has to be published for APM unmodified
#     828         # so we make a shallow copy here before adding updatedExisting.
# --> 829         result = sock_info.command(
#     830             self.__database.name,
#     831             command,
#
# ~\anaconda3\lib\site-packages\pymongo\pool.py in command(self, dbname, spec, slave_ok, read_preference, codec_options, check, allowable_errors, check_keys, read_concern, write_concern, parse_write_concern_error, collation, session, client, retryable_write, publish_events, user_fields, exhaust_allowed)
#     697         # Catch socket.error, KeyboardInterrupt, etc. and close ourselves.
#     698         except BaseException as error:
# --> 699             self._raise_connection_failure(error)
#     700
#     701     def send_message(self, message, max_doc_size):
#
# ~\anaconda3\lib\site-packages\pymongo\pool.py in command(self, dbname, spec, slave_ok, read_preference, codec_options, check, allowable_errors, check_keys, read_concern, write_concern, parse_write_concern_error, collation, session, client, retryable_write, publish_events, user_fields, exhaust_allowed)
#     681             self._raise_if_not_writable(unacknowledged)
#     682         try:
# --> 683             return command(self, dbname, spec, slave_ok,
#     684                            self.is_mongos, read_preference, codec_options,
#     685                            session, client, check, allowable_errors,
#
# ~\anaconda3\lib\site-packages\pymongo\network.py in command(sock_info, dbname, spec, slave_ok, is_mongos, read_preference, codec_options, session, client, check, allowable_errors, address, check_keys, listeners, max_bson_size, read_concern, parse_write_concern_error, collation, compression_ctx, use_op_msg, unacknowledged, user_fields, exhaust_allowed)
#     148             response_doc = {"ok": 1}
#     149         else:
# --> 150             reply = receive_message(sock_info, request_id)
#     151             sock_info.more_to_come = reply.more_to_come
#     152             unpacked_docs = reply.unpack_response(
#
# ~\anaconda3\lib\site-packages\pymongo\network.py in receive_message(sock_info, request_id, max_message_size)
#     193     # Ignore the response's request id.
#     194     length, _, response_to, op_code = _UNPACK_HEADER(
# --> 195         _receive_data_on_socket(sock_info, 16, deadline))
#     196     # No request_id for exhaust cursor "getMore".
#     197     if request_id is not None:
#
# ~\anaconda3\lib\site-packages\pymongo\network.py in _receive_data_on_socket(sock_info, length, deadline)
#     284             try:
#     285                 wait_for_read(sock_info, deadline)
# --> 286                 chunk_length = sock_info.sock.recv_into(mv[bytes_read:])
#     287             except (IOError, OSError) as exc:
#     288                 if _errno_from_exception(exc) == errno.EINTR:
#
# ~\anaconda3\lib\site-packages\pymongo\pyopenssl_context.py in recv_into(self, *args, **kwargs)
#     127     def recv_into(self, *args, **kwargs):
#     128         try:
# --> 129             return self._call(super(_sslConn, self).recv_into, *args, **kwargs)
#     130         except _SSL.SysCallError as exc:
#     131             # Suppress ragged EOFs to match the stdlib.
#
# ~\anaconda3\lib\site-packages\pymongo\pyopenssl_context.py in _call(self, call, *args, **kwargs)
#     105         while True:
#     106             try:
# --> 107                 return call(*args, **kwargs)
#     108             except _RETRY_ERRORS:
#     109                 self.socket_checker.select(
#
# ~\anaconda3\lib\site-packages\OpenSSL\SSL.py in recv_into(self, buffer, nbytes, flags)
#    1837             result = _lib.SSL_peek(self._ssl, buf, nbytes)
#    1838         else:
# -> 1839             result = _lib.SSL_read(self._ssl, buf, nbytes)
#    1840         self._raise_ssl_error(self._ssl, result)
#    1841
#
# KeyboardInterrupt:

# %%
# Out:
# False    56353
# True      5695
# Name: dado_valido, dtype: int64

# %%
aux
# Out:
#        0 Faturamento Funcionarios  \
# 0    NaN         NaN          NaN
# 1    NaN         NaN          NaN
# 2    NaN         NaN          NaN
# 3    NaN         NaN          NaN
# 4    NaN         NaN          NaN
# ...   ..         ...          ...
# 5690 NaN         NaN          NaN
# 5691 NaN         NaN          NaN
# 5692 NaN         NaN          NaN
# 5693 NaN         NaN          NaN
# 5694 NaN         NaN          NaN
#
#                                                    Nome OpcaoTributaria  \
# 0                        EIKON SISTEMAS DE ENERGIA LTDA             NaN
# 1                   MIRANDELA ARTEFATOS DE PAPEL EIRELI             NaN
# 2                  E. H. CONSTANTINO & CONSTANTINO LTDA             NaN
# 3                INDUSTRIA DE ALIMENTOS PATA NEGRA LTDA             NaN
# 4                        IBBL TECNOLOGIA EM AGUA EIRELI             NaN
# ...                                                 ...             ...
# 5690      METALURGICA SARAIVA INDUSTRIA E COMERCIO LTDA             NaN
# 5691                            SAPORITI DO BRASIL LTDA             NaN
# 5692                               ELCO DO BRASIL LTDA.             NaN
# 5693  RG COPPER INDUSTRIA E COMERCIO DE CONDUTORES E...             NaN
# 5694               COMPENSADOS E LAMINADOS LAVRASUL S/A             NaN
#
#        Porte          ReceitaAbertura  \
# 0     DEMAIS  2013-12-16T00:00:00.000
# 1        EPP  1970-01-20T00:00:00.000
# 2        EPP  2006-03-27T00:00:00.000
# 3       None  2008-07-11T00:00:00.000
# 4     DEMAIS  1986-10-08T00:00:00.000
# ...      ...                      ...
# 5690  DEMAIS  1978-07-11T00:00:00.000
# 5691  DEMAIS  1999-05-03T00:00:00.000
# 5692  DEMAIS  1998-11-17T00:00:00.000
# 5693  DEMAIS  2014-09-16T00:00:00.000
# 5694  DEMAIS  1973-08-27T00:00:00.000
#
#                                        ReceitaAtividade  ReceitaCapitalSocial  \
# 0     27.10-4/02 Fabricação de transformadores, indu...              140000.0
# 1      17.31-1/00 Fabricação de embalagens de papel\r\n              100000.0
# 2        10.13-9/01 Fabricação de produtos de carne\r\n              140000.0
# 3        10.13-9/01 Fabricação de produtos de carne\r\n               50000.0
# 4     27.59-7/99 Fabricação de outros aparelhos elet...            21641000.0
# ...                                                 ...                   ...
# 5690  29.49-2/99 Fabricação de outras peças e acessó...             5000000.0
# 5691  10.99-6/99 Fabricação de outros produtos alime...             1766364.0
# 5692  28.23-2/00 Fabricação de máquinas e aparelhos ...              100000.0
# 5693  27.33-3/00 Fabricação de fios, cabos e conduto...              200000.0
# 5694  16.22-6/02 Fabricação de esquadrias de madeira...            10936137.0
#
#                                 ReceitaNaturezaJuridica ReceitaSituacao  \
# 0                 206-2 - Sociedade Empresária Limitada           ATIVA
# 1     230-5 - Empresa Individual de Responsabilidade...           ATIVA
# 2                 206-2 - Sociedade Empresária Limitada           ATIVA
# 3                 206-2 - Sociedade Empresária Limitada           ATIVA
# 4     230-5 - Empresa Individual de Responsabilidade...           ATIVA
# ...                                                 ...             ...
# 5690              206-2 - Sociedade Empresária Limitada           ATIVA
# 5691              206-2 - Sociedade Empresária Limitada           ATIVA
# 5692              206-2 - Sociedade Empresária Limitada           ATIVA
# 5693              206-2 - Sociedade Empresária Limitada           ATIVA
# 5694                  205-4 - Sociedade Anônima Fechada           ATIVA
#
#      ReceitaSituacaoEspecial TotalProtesto UfEndereco ValorProtesto  \
# 0                                      NaN         SC           NaN
# 1                                      NaN         RJ           NaN
# 2                                      NaN         PR           NaN
# 3                                      NaN         RJ           NaN
# 4                                      NaN         SP           NaN
# ...                      ...           ...        ...           ...
# 5690                                   NaN         SC           NaN
# 5691                                   NaN         PR           NaN
# 5692                                   NaN         SP           NaN
# 5693                                   NaN         SP           NaN
# 5694                                   NaN         SC           NaN
#
#                 cnpj resultado
# 0     19418139000188        -1
# 1     29925344000193        -1
# 2     07912350000173        -1
# 3     10171633000116        -1
# 4     56505464000104        -1
# ...              ...       ...
# 5690  50185891000176        -1
# 5691  03129956000186        -1
# 5692  02860574000165        -1
# 5693  21044682000104        -1
# 5694  83187930001367       NaN
#
# [5695 rows x 17 columns]

# %%
dado_valido = False
if len() > 0 :
    dado_valido = True
# Out:
#                             _id            cnpj resultado  \
# 0      60dca5d720cf7db6c1129ac4  14280184000103        -1
# 1      60dca5d720cf7db6c1129ac5  13565641000135        -1
# 2      60dca5d720cf7db6c1129ac6  18716040000108        -1
# 3      60dca5d720cf7db6c1129ac7  06286939000140        -1
# 4      60dca5d720cf7db6c1129ac8  64435357000185        -1
# ...                         ...             ...       ...
# 62043  60e8383c218a007683d4f5ee  07559270000186        -1
# 62044  60e8383e218a007683d506e1  05110926000153        -1
# 62045  60e8383f218a007683d51b47  19765906000125        -1
# 62046  60e83845218a007683d55b54  29474162000143        -1
# 62047  60e8384e218a007683d5c74f  08381735000114        -1
#
#                                              serasa_info  \
# 0      {'8_TOTAL_FALENCIA_REQ': nan, '8_TOTAL_FALENCI...
# 1      {'8_TOTAL_FALENCIA_REQ': nan, '8_TOTAL_FALENCI...
# 2      {'8_TOTAL_FALENCIA_REQ': nan, '8_TOTAL_FALENCI...
# 3      {'8_TOTAL_FALENCIA_REQ': nan, '8_TOTAL_FALENCI...
# 4      {'8_TOTAL_FALENCIA_REQ': nan, '8_TOTAL_FALENCI...
# ...                                                  ...
# 62043  {'8_TOTAL_FALENCIA_REQ': nan, '8_TOTAL_FALENCI...
# 62044  {'8_TOTAL_FALENCIA_REQ': nan, '8_TOTAL_FALENCI...
# 62045  {'8_TOTAL_FALENCIA_REQ': nan, '8_TOTAL_FALENCI...
# 62046  {'8_TOTAL_FALENCIA_REQ': nan, '8_TOTAL_FALENCI...
# 62047  {'8_TOTAL_FALENCIA_REQ': nan, '8_TOTAL_FALENCI...
#
#       classificacao_modelo1  predicao_modelo1 dado_valido  \
# 0                       Bom            0.7971       False
# 1                 Muito Bom            0.8312       False
# 2                       Bom            0.7957       False
# 3                       Bom            0.6602       False
# 4                       Bom            0.6620       False
# ...                     ...               ...         ...
# 62043                   NaN           -1.0000         NaN
# 62044                   NaN           -1.0000         NaN
# 62045                   NaN           -1.0000         NaN
# 62046                   NaN           -1.0000         NaN
# 62047                   NaN           -1.0000         NaN
#
#                                                vadu_info  \
# 0      {'Nome': 'EDINHO SUPERMERCADO LTDA', 'Porte': ...
# 1      {'Nome': 'TORRES E MENEZES COMERCIAL LTDA', 'P...
# 2      {'Nome': 'GRAN-COPA ARMAZENS GERAIS LTDA', 'Po...
# 3      {'Nome': 'COMERCIO DE GENEROS ALIMENTICIOS SAO...
# 4      {'Nome': 'ANAIM AUTO PECAS E ACESSORIOS LTDA',...
# ...                                                  ...
# 62043                                                NaN
# 62044                                                NaN
# 62045                                                NaN
# 62046                                                NaN
# 62047                                                NaN
#
#       classificacao_modelo3  predicao_modelo3 vadu_dict
# 0                       NaN               NaN       NaN
# 1                       NaN               NaN       NaN
# 2                       NaN               NaN       NaN
# 3                       NaN               NaN       NaN
# 4                       NaN               NaN       NaN
# ...                     ...               ...       ...
# 62043                   NaN              -1.0       NaN
# 62044                   NaN              -1.0       NaN
# 62045                   NaN              -1.0       NaN
# 62046                   NaN              -1.0       NaN
# 62047                   NaN              -1.0       NaN
#
# [62048 rows x 11 columns]

# %%
myclient = pymongo.MongoClient(CONNETCION_MONGO)
mydb = myclient["atf_score"]
mycol = mydb['models-collection']
cursor = mycol.find({'model_name':model_name})
df = pd.DataFrame(list(cursor))

# %%
LISTA_UfEndereco = ['RS', 'SC', 'PR', 'SP', 'RJ', 'MG']
LISTA_ReceitaSituacao = ['ATIVA']
TEMPO_ReceitaAbertura = 3
LISTA_ReceitaNaturezaJuridica = ['203-8 - Sociedade de Economia Mista', '204-6 - Sociedade Anônima Aberta', '205-4 - Sociedade Anônima Fechada', '206-2 - Sociedade Empresária Limitada', '208-9 - Sociedade Empresária em Comandita Simples', '209-7 - Sociedade Empresária em Comandita por Ações', '230-5 - Empresa Individual de Responsabilidade Limitada (de Natureza Empresária)', '231-3 - Empresa Individual de Responsabilidade Limitada (de Natureza Simples)']
LISTA_ReceitaSituacaoEspecial = ['RECUPERACAO JUDICIAL','']
VALOR_ReceitaCapitalSocial = 10000
LISTA_OpcaoTributaria = ['SIMEI','SIMPLES NACIONAL']
LISTA_Porte = ['MEI','ME']
LISTA_ReceitaAtividade = ['C', 'P']

# %%
dict_cutsRules = {"UfEndereco" : ['RS', 'SC', 'PR', 'SP', 'RJ', 'MG'],
"ReceitaSituacao" : ['ATIVA'],
"ReceitaAbertura" : 3,
"ReceitaNaturezaJuridica" : ['203-8 - Sociedade de Economia Mista', '204-6 - Sociedade Anônima Aberta', '205-4 - Sociedade Anônima Fechada', '206-2 - Sociedade Empresária Limitada', '208-9 - Sociedade Empresária em Comandita Simples', '209-7 - Sociedade Empresária em Comandita por Ações', '230-5 - Empresa Individual de Responsabilidade Limitada (de Natureza Empresária)', '231-3 - Empresa Individual de Responsabilidade Limitada (de Natureza Simples)'],
"ReceitaSituacaoEspecial" : ['RECUPERACAO JUDICIAL',''],
"ReceitaCapitalSocial" : 10000,
"OpcaoTributaria" : ['SIMEI','SIMPLES NACIONAL'],
"Porte" : ['MEI','ME'],
"ReceitaAtividade" : ['C', 'P']}

# %%
mycol.insert_one(dict_cutsRules)
