# %%
import pymongo
import pandas as pd
import json

# %%
from datetime import datetime

# %%
df = pd.read_csv('seras.csv', sep = ";", header=None )
# Out:
# C:\Users\rafae\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (2,8,9,14) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df[0] = df[0].astype(int, errors = 'ignore')

# %%
myclient = pymongo.MongoClient("mongodb://localhost:27017/")
mydb = myclient["test"]
mycol = mydb['initial-collection']

# %%
many_list = []

for i,j in df[df[9].notnull()].iterrows():
    query = { "cnpj": j[0] };
    dict_add = { "cnpj":j[0],
                "txt_type":"PURO",
                "txt_content":j[9],
                "isProcessed":False,
                "insertDate":datetime.now() }
    update = { "$set": dict_add};
    many_list.append(dict_add)
#     options = { "upsert": True };
    
#     mycol.update_one(query, update, upsert=True);

# %%
mycol.insert_many(many_list)

# %%
cursor = mycol.find({'result': {'$ne': -1}})

# %%
pd.DataFrame(list(cursor)).to_csv('TrainBase.csv')
